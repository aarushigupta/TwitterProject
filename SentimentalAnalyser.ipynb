# %%
from keys import *
import tweepy

# %%
auth = tweepy.AppAuthHandler(API_KEY, API_SECRET)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
if (not api):
    print ("Can't Authenticate")
    sys.exit(-1)

# %%
searchQuery = '#yoga'
tweetsPerQry = 100

# %%
tweets = api.search(q=searchQuery, count=tweetsPerQry)

# %%
print tweets[1]
# Out:
# Status(contributors=None, truncated=False, text=u'RT @SadhguruJV: We have a dominant place on this planet because of our ability to use tools. #Yoga is a subjective tool for our inner wellb\u2026', is_quote_status=False, in_reply_to_status_id=None, id=876340597677727744, favorite_count=0, _api=<tweepy.api.API object at 0x103933b50>, author=User(follow_request_sent=None, has_extended_profile=True, profile_use_background_image=True, _json={u'follow_request_sent': None, u'has_extended_profile': True, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 135899593, u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png', u'verified': False, u'translator_type': u'none', u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/723799481309908992/ZErzCU2z_normal.jpg', u'profile_sidebar_fill_color': u'DDEEF6', u'entities': {u'description': {u'urls': []}}, u'followers_count': 219, u'profile_sidebar_border_color': u'C0DEED', u'id_str': u'135899593', u'profile_background_color': u'C0DEED', u'listed_count': 2, u'is_translation_enabled': False, u'utc_offset': 19800, u'statuses_count': 1612, u'description': u'Human Resource Specialist - Oil & Gas, Engineering Industry...\nProud to be Indian! Har Har Mahadev!!!', u'friends_count': 62, u'location': u'India', u'profile_link_color': u'1DA1F2', u'profile_image_url': u'http://pbs.twimg.com/profile_images/723799481309908992/ZErzCU2z_normal.jpg', u'following': None, u'geo_enabled': False, u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/135899593/1494052149', u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png', u'screen_name': u'Namratakm', u'lang': u'en', u'profile_background_tile': False, u'favourites_count': 865, u'name': u'Namrata Mirchandani', u'notifications': None, u'url': None, u'created_at': u'Thu Apr 22 14:07:13 +0000 2010', u'contributors_enabled': False, u'time_zone': u'Asia/Calcutta', u'protected': False, u'default_profile': True, u'is_translator': False}, time_zone=u'Asia/Calcutta', id=135899593, description=u'Human Resource Specialist - Oil & Gas, Engineering Industry...\nProud to be Indian! Har Har Mahadev!!!', _api=<tweepy.api.API object at 0x103933b50>, verified=False, profile_text_color=u'333333', profile_image_url_https=u'https://pbs.twimg.com/profile_images/723799481309908992/ZErzCU2z_normal.jpg', profile_sidebar_fill_color=u'DDEEF6', is_translator=False, geo_enabled=False, entities={u'description': {u'urls': []}}, followers_count=219, protected=False, id_str=u'135899593', default_profile_image=False, listed_count=2, lang=u'en', utc_offset=19800, statuses_count=1612, profile_background_color=u'C0DEED', friends_count=62, profile_link_color=u'1DA1F2', profile_image_url=u'http://pbs.twimg.com/profile_images/723799481309908992/ZErzCU2z_normal.jpg', notifications=None, default_profile=True, profile_background_image_url_https=u'https://abs.twimg.com/images/themes/theme1/bg.png', profile_banner_url=u'https://pbs.twimg.com/profile_banners/135899593/1494052149', profile_background_image_url=u'http://abs.twimg.com/images/themes/theme1/bg.png', name=u'Namrata Mirchandani', is_translation_enabled=False, profile_background_tile=False, favourites_count=865, screen_name=u'Namratakm', url=None, created_at=datetime.datetime(2010, 4, 22, 14, 7, 13), contributors_enabled=False, location=u'India', profile_sidebar_border_color=u'C0DEED', translator_type=u'none', following=False), _json={u'contributors': None, u'truncated': False, u'text': u'RT @SadhguruJV: We have a dominant place on this planet because of our ability to use tools. #Yoga is a subjective tool for our inner wellb\u2026', u'is_quote_status': False, u'in_reply_to_status_id': None, u'id': 876340597677727744, u'favorite_count': 0, u'entities': {u'symbols': [], u'user_mentions': [{u'id': 67611162, u'indices': [3, 14], u'id_str': u'67611162', u'screen_name': u'SadhguruJV', u'name': u'Sadhgu ...
